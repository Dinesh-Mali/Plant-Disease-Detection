# %% [markdown]
# ## Plant Disease Detection App

# %% [markdown]
# #### In this project we will create a Convolutional Neural Network which will be able to predict whether a plant is suffering from a disease. We will use different layers and other hyperparameters for building, training and testing this classifictaion model.We will be using tensorflow and keras for this project.

# %% [markdown]
# #### Next we will import all the required libraries. As we are making a CNN model we will import all the required layers, activations, optimizers, etc.

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from matplotlib.image import imread
import cv2
import random
import os
from os import listdir
from PIL import Image
from sklearn.preprocessing import label_binarize,  LabelBinarizer
from keras.preprocessing import image
from keras.preprocessing.image import img_to_array, array_to_img
from keras.optimizers import Adam
from keras.models import Sequential
from keras.layers import Conv2D, MaxPooling2D
from keras.layers import Activation, Flatten, Dropout, Dense
from sklearn.model_selection import train_test_split
from keras.models import model_from_json
from keras.utils import to_categorical
# Out:
# Using TensorFlow backend.

# %%
from tensorflow.keras.preprocessing import image
from tensorflow.keras.preprocessing.image import img_to_array, array_to_img
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Conv2D, MaxPooling2D, Activation, Flatten, Dropout, Dense
from sklearn.model_selection import train_test_split
from tensorflow.keras.models import model_from_json
from tensorflow.keras.utils import to_categorical

# %% [markdown]
# #### Now we will observe some of the iamges that are their in our dataset. We will plot 12 images here using the matplotlib library.

# %%
# Plotting 12 images to check dataset
plt.figure(figsize=(12,12))
path = "data/Plant_images/Potato___Early_blight"
for i in range(1,17):
    plt.subplot(4,4,i)
    plt.tight_layout()
    rand_img = imread(path +'/'+ random.choice(sorted(os.listdir(path))))
    plt.imshow(rand_img)
    plt.xlabel(rand_img.shape[1], fontsize = 10)#width of image
    plt.ylabel(rand_img.shape[0], fontsize = 10)#height of image

# %% [markdown]
# #### After visualizing the images let us move forward and create a function which will convert the images into a numpy array. It is required because we will normalize our dataset after this.

# %%
#Converting Images to array 
def convert_image_to_array(image_dir):
    try:
        image = cv2.imread(image_dir)
        if image is not None :
            image = cv2.resize(image, (256,256))  
            #image = cv2.cvtColor(image, cv2.COLOR_BGR2GRAY) 
            return img_to_array(image)
        else :
            return np.array([])
    except Exception as e:
        print(f"Error : {e}")
        return None

# %% [markdown]
# #### Now we will convert all the images into numpy array.

# %%
dir = "data/Plant_images"
root_dir = listdir(dir)
image_list, label_list = [], []
all_labels = ['Corn-Common_rust', 'Potato-Early_blight', 'Tomato-Bacterial_spot']
binary_labels = [0,1,2]
temp = -1

# Reading and converting image to numpy array
for directory in root_dir:
    plant_image_list = listdir(f"{dir}/{directory}")
    temp += 1
    for files in plant_image_list:
        image_path = f"{dir}/{directory}/{files}"
        image_list.append(convert_image_to_array(image_path))
        label_list.append(binary_labels[temp])

# %% [markdown]
# #### We will also observe the number of images under different classes to see if the dataset is balanced or not

# %%
# Visualize the number of classes count
label_counts = pd.DataFrame(label_list).value_counts()
label_counts.head()
# Out:
# 2    300
# 1    300
# 0    300
# dtype: int64

# %% [markdown]
# #### Next we will observe the shape of the image.

# %%
image_list[0].shape
# Out:
# (256, 256, 3)

# %% [markdown]
# #### Checking the total number of the images which is the length of the labels list.

# %%
label_list = np.array(label_list)
label_list.shape
# Out:
# (900,)

# %% [markdown]
# #### Next we will use sklearn train_test_split to split the dataset into testing and training data. Here I have taken test size as 0.2 so my data will be divided into 80% training and 20% testing data.

# %%
x_train, x_test, y_train, y_test = train_test_split(image_list, label_list, test_size=0.2, random_state = 10)

# %% [markdown]
# #### Now we will normalize the dataset of our images. As pixel values ranges from 0 to 255 so we will divide each image pixel with 255 to normalize the dataset.

# %%
x_train = np.array(x_train, dtype=np.float16) / 225.0
x_test = np.array(x_test, dtype=np.float16) / 225.0
x_train = x_train.reshape( -1, 256,256,3)
x_test = x_test.reshape( -1, 256,256,3)

# %%
y_train = to_categorical(y_train)
y_test = to_categorical(y_test)

# %% [markdown]
# #### Next we will create a network architecture for the model.
#
# #### We have used different types of layers according to their features namely Conv_2d (It is used to create a convolutional kernel that is convolved with the input layer to produce the output tensor), max_pooling2d (It is a downsampling technique which takes out the maximum value over the window defined by poolsize), flatten (It flattens the input and creates a 1D output), Dense (Dense layer produce the output as the dot product of input and kernel).

# %%
model = Sequential()
model.add(Conv2D(32, (3, 3), padding="same",input_shape=(256,256,3), activation="relu"))
model.add(MaxPooling2D(pool_size=(3, 3)))
model.add(Conv2D(16, (3, 3), padding="same", activation="relu"))
model.add(MaxPooling2D(pool_size=(2, 2)))
model.add(Flatten())
model.add(Dense(8, activation="relu"))
model.add(Dense(3, activation="softmax"))
model.summary()
# Out:
# Model: "sequential_1"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d_1 (Conv2D)            (None, 256, 256, 32)      896
# _________________________________________________________________
# max_pooling2d_1 (MaxPooling2 (None, 85, 85, 32)        0
# _________________________________________________________________
# conv2d_2 (Conv2D)            (None, 85, 85, 16)        4624
# _________________________________________________________________
# max_pooling2d_2 (MaxPooling2 (None, 42, 42, 16)        0
# _________________________________________________________________
# flatten_1 (Flatten)          (None, 28224)             0
# _________________________________________________________________
# dense_1 (Dense)              (None, 8)                 225800
# _________________________________________________________________
# dense_2 (Dense)              (None, 3)                 27
# =================================================================
# Total params: 231,347
# Trainable params: 231,347
# Non-trainable params: 0
# _________________________________________________________________

# %% [markdown]
# #### While compiling the model we need to set the type of loss which will be Binary Crossentropy for our model alongwith this we also need to set the optimizer and the metrics respectively.

# %%
model.compile(loss = 'categorical_crossentropy', optimizer = Adam(0.0001),metrics=['accuracy'])

# %% [markdown]
# #### Next we will split the dataset into validation and training data.

# %%
# Splitting the training data set into training and validation data sets
x_train, x_val, y_train, y_val = train_test_split(x_train, y_train, test_size = 0.2)

# %%
# Training the model
epochs = 20
batch_size = 128
history = model.fit(x_train, y_train, batch_size = batch_size, epochs = epochs, 
                    validation_data = (x_val, y_val))
# Out:
# Train on 576 samples, validate on 144 samples
# Epoch 1/20
# 576/576 [==============================] - 57s 99ms/step - loss: 1.0659 - accuracy: 0.3524 - val_loss: 1.0341 - val_accuracy: 0.2778
# Epoch 2/20
# 576/576 [==============================] - 56s 98ms/step - loss: 0.9730 - accuracy: 0.4844 - val_loss: 0.9551 - val_accuracy: 0.5347
# Epoch 3/20
# 576/576 [==============================] - 56s 97ms/step - loss: 0.8778 - accuracy: 0.6354 - val_loss: 0.8419 - val_accuracy: 0.5486
# Epoch 4/20
# 576/576 [==============================] - 56s 98ms/step - loss: 0.7718 - accuracy: 0.7083 - val_loss: 0.7324 - val_accuracy: 0.7708
# Epoch 5/20
# 576/576 [==============================] - 56s 98ms/step - loss: 0.6582 - accuracy: 0.8767 - val_loss: 0.6078 - val_accuracy: 0.9236
# Epoch 6/20
# 576/576 [==============================] - 57s 98ms/step - loss: 0.5446 - accuracy: 0.9444 - val_loss: 0.4870 - val_accuracy: 0.9861
# Epoch 7/20
# 576/576 [==============================] - 56s 97ms/step - loss: 0.4428 - accuracy: 0.9688 - val_loss: 0.3952 - val_accuracy: 0.9722
# Epoch 8/20
# 576/576 [==============================] - 56s 97ms/step - loss: 0.3568 - accuracy: 0.9566 - val_loss: 0.3153 - val_accuracy: 0.9931
# Epoch 9/20
# 576/576 [==============================] - 56s 97ms/step - loss: 0.2846 - accuracy: 0.9670 - val_loss: 0.2497 - val_accuracy: 0.9931
# Epoch 10/20
# 576/576 [==============================] - 56s 97ms/step - loss: 0.2324 - accuracy: 0.9774 - val_loss: 0.2058 - val_accuracy: 0.9861
# Epoch 11/20
# 576/576 [==============================] - 55s 96ms/step - loss: 0.1918 - accuracy: 0.9722 - val_loss: 0.1784 - val_accuracy: 0.9931
# Epoch 12/20
# 576/576 [==============================] - 56s 98ms/step - loss: 0.1583 - accuracy: 0.9809 - val_loss: 0.1437 - val_accuracy: 0.9931
# Epoch 13/20
# 576/576 [==============================] - 56s 98ms/step - loss: 0.1337 - accuracy: 0.9826 - val_loss: 0.1365 - val_accuracy: 0.9931
# Epoch 14/20
# 576/576 [==============================] - 57s 98ms/step - loss: 0.1164 - accuracy: 0.9861 - val_loss: 0.1196 - val_accuracy: 0.9861
# Epoch 15/20
# 576/576 [==============================] - 58s 101ms/step - loss: 0.1077 - accuracy: 0.9757 - val_loss: 0.1500 - val_accuracy: 0.9583
# Epoch 16/20
# 576/576 [==============================] - 61s 106ms/step - loss: 0.1055 - accuracy: 0.9792 - val_loss: 0.1018 - val_accuracy: 0.9792
# Epoch 17/20
# 576/576 [==============================] - 63s 110ms/step - loss: 0.0978 - accuracy: 0.9757 - val_loss: 0.1186 - val_accuracy: 0.9653
# Epoch 18/20
# 576/576 [==============================] - 62s 107ms/step - loss: 0.0829 - accuracy: 0.9826 - val_loss: 0.0792 - val_accuracy: 0.9931
# Epoch 19/20
# 576/576 [==============================] - 58s 101ms/step - loss: 0.0666 - accuracy: 0.9931 - val_loss: 0.0929 - val_accuracy: 0.9931
# Epoch 20/20
# 576/576 [==============================] - 52s 91ms/step - loss: 0.0608 - accuracy: 0.9965 - val_loss: 0.0702 - val_accuracy: 0.9931

# %% [markdown]
# #### Fitting the model with the data and finding out the accuracy at each epoch to see how our model is learning.
#
# #### Now we will train our model on 20 epochs and a batch size of 128. You can try using more number of epochs to increase accuracy but here we can see that the model has already raeched a very high accuracy so we don't need to run it for more. During each epochs we can see how the model is performing by viewing the training and validation accuracy.

# %% [markdown]
# #### Saving the model using different techniques.

# %%
model.save("plant_disease.h5")
# serialize model to json
json_model = model.to_json()
#save the model architecture to JSON file
with open('plant_model.json', 'w') as json_file:
    json_file.write(json_model)
#saving the weights of the model
model.save_weights('plant_model_weights.h5')

# %% [markdown]
# #### Next we will plot the accuracy of the model for the trainig history.

# %%
#Plot the training history
plt.figure(figsize=(12, 5))
plt.plot(history.history['accuracy'], color='r')
plt.plot(history.history['val_accuracy'], color='b')
plt.title('Model Accuracy')
plt.ylabel('Accuracy')
plt.xlabel('Epochs')
plt.legend(['train', 'val'])

plt.show()

# %% [markdown]
# #### Evaluating the model to know the accuracy of the model.

# %%
print("[INFO] Calculating model accuracy")
scores = model.evaluate(x_test, y_test)
print(f"Test Accuracy: {scores[1]*100}")
# Out:
# [INFO] Calculating model accuracy
# 180/180 [==============================] - 6s 34ms/step
# Test Accuracy: 98.88888597488403

# %% [markdown]
# #### Next we will use our model to predict predicting the testing dataset label.

# %%
y_pred = model.predict(x_test)

# %%
# Plotting image to compare
img = array_to_img(x_test[10])
img
# Out:
# <PIL.Image.Image image mode=RGB size=256x256 at 0x7FA8F2890E80>

# %% [markdown]
# #### Printing out the original and the predicted label.

# %%
# Finding max value from predition list and comaparing original value vs predicted
print("Originally : ",all_labels[np.argmax(y_test[10])])
print("Predicted : ",all_labels[np.argmax(y_pred[10])])
# Out:
# Originally :  Potato-Early_blight
# Predicted :  Potato-Early_blight

# %% [markdown]
# ## Conclusion

# %% [markdown]
# #### We started with loading the dataset into google colab using google drive and visualizing the images. Normalizing is an important step when working with any type of dataset. After that we created a CNN Model which is further used for predicting the plant diseases using the image supplied to model.
#
# #### This model is highly beneficial as it can be used by different agricultural firms and farmers to increase their yield and stop wastage of crops due to disease.
